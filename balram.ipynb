# %%
import os
import glob
import imagehash
import cv2
from PIL import Image
import uuid

# %%
longvideoList = []
def longValueHashValue(images,fileName):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    for path in full_path:
        folder_imges=path.split('/')[-1] ####W
        hashes= imagehash.average_hash(Image.open(path),16)
        longvideoList.append(hashes)
    return True

longVideo = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/long/output8.mp4"

fileName = longVideo.split('/')[-1]            #finaldic[fileName] = dictionary
ide = longVideo.split("/")[-1].split(".")[-1] 
image_path=longVideo + ide + "long"       
if not os.path.exists(image_path):
    os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -i {} -vf fps=5 {}/{}%d.jpg".format(longVideo,image_path,random)
    os.system(cmd)
    longValueHashValue(image_path, fileName)
print(len(longvideoList),'length=???>>>')

finaldic = {}
def hashvalue(images,fileName, finaldic):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    dictionary={}    
    matchCount = 0
    totalCount = len(full_path)
    smallVideoList = []
    for path in full_path:
        folder_imges=path.split('/')[-1]
        hashes= imagehash.average_hash(Image.open(path),16)
        smallVideoList.append(hashes)
        for l in longvideoList: 
            if(l == hashes):
                print(l == hashes, l, '---->', hashes, fileName)
                matchCount = matchCount+1
                break
    smallVideoList = []
    dictionary['matchCount'] = matchCount
    dictionary['totalCount'] = totalCount
    matchCount = 0
    finaldic[fileName] = dictionary
    return True

folder_prefix  = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/"    
all_file = glob.glob(folder_prefix + "*.mp4")
i = 0
for file in all_file:
    fileName = file.split('/')[-1]            #finaldic[fileName] = dictionary
    ide = file.split("/")[-1].split(".")[-1]
    image_path=folder_prefix + ide + str(i)       
    if not os.path.exists(image_path):
        os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -i {} -vf fps=5 {}/{}%d.jpg".format(file,image_path,random)
    os.system(cmd)
    flag = hashvalue(image_path, fileName , finaldic)
    i= i+1
print(finaldic,'test')
def convertToPercent(myDict):
    percentDict = {}
    for i in myDict.keys():
        prcent = (int(myDict[i]['matchCount'])/int(myDict[i]['totalCount']))*100
        percentDict[i] = prcent
        #print("Key"+" " + i + " " + str(myDict[i]['matchCount']) + " " + str(myDict[i]['totalCount']))
    print(percentDict)
convertToPercent(finaldic)
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
walongVideo = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/long/output8.mp4"

ide=walongVideo.split("/")[-1].split(".")[-1]

tud=walongVideo + ide +'tshar'

# %%
tud
# Out:
# '/home/link-lap-24/Downloads/golf_june7/projet/input_video/long/output8.mp4mp4tshar'

# %%
adding_has={}
def hashes(images_path):
    imag =(images_path + "*jpg")
    jpg_files=glob.glob(imag)
    
    for i in jpg_files:
        tus=i.split("/")[-1]
        hs=imagehash.average_hash(Image.open(i),16)
        adding_has[hs]=tus
#         adding_has.append(hs)

    return True
    
images_pth="/home/link-lap-24/Downloads/handball_june30/Output/Output_5/"

hashes(images_pth)

print(adding_has)
# Out:
# {array([[False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False,  True,  True,  True,  True,
#          True, False, False, False,  True,  True, False],
#        [False,  True, False,  True,  True,  True,  True,  True,  True,
#          True, False, False, False, False,  True, False],
# ...

# %%
dictionary={}    


matchCount=0
dictionary['MatchCount']=matchCount

# %%
print(dictionary)
# Out:
# {'MatchCount': 0}

# %%
longvideoList = []
def longValueHashValue(images,fileName):  # 1st-filename=Creating Frames or 2nd-images=Hashvalues
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    for path in full_path:
        folder_imges=path.split('/')[-1] ####W
        hashes= imagehash.average_hash(Image.open(path),16)
        longvideoList.append(hashes)
    return True

longVideo = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/long/output8.mp4"

fileName = longVideo.split('/')[-1]            #finaldic[fileName] = dictionary
ide = longVideo.split("/")[-1].split(".")[-1] 
image_path=longVideo + ide + "long"       
if not os.path.exists(image_path):
    os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -i {} -vf fps=5 {}/{}%d.jpg".format(longVideo,image_path,random)
    os.system(cmd)
    longValueHashValue(image_path, fileName)
print(len(longvideoList),'length=???>>>')

# %%
longvideoList = []
def longValueHashValue(all_folder_images_path_for_hash,video_path_for_frmes):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    for path in full_path:
        folder_imges=path.split('/')[-1] ####W
        hashes= imagehash.average_hash(Image.open(path),16)
        longvideoList.append(hashes)
    return True

longVideo = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/long/output8.mp4"
fileName = longVideo.split('/')[-1]            #finaldic[fileName] = dictionary
ide = longVideo.split("/")[-1].split(".")[-1] 
videos_path=longVideo + ide + "long"       
if not os.path.exists(image_path):
    os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -i {} -vf fps=5 {}/{}%d.jpg".format(longVideo,image_path,random)
    os.system(cmd)
    
    longValueHashValue(videos_path, fileName)
print(len(longvideoList),'length=???>>>')

# %%
# folder_prefix  = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/"  


# all_file = glob.glob(folder_prefix + "*.mp4")


# for path in all_file:
#     fileName = path.split('/')[-1]            #for selecting only specific folder
#     ide=path.split('/')[-1].split(".")[-1]
#     new_name=ide.replace(ide,fileName)
#     print(new_name)
# #     if not os.path.exists(s_folders):
# #         os.mkdir(s_folders)
    
# #     random=str(uuid.uuid4())    
# #     cmd='ffmpeg -i {} -vf fps=5 {}/{}%d.jpg'.format(path,s_folders,random)
# #     os.system(cmd)
# Out:
# input3.mp4
# input5.mp4
# input1.mp4
# input2.mp4
# input4.mp4
# inputc6.mp4

# %%
import os
import glob
import imagehash
import cv2
from PIL import Image
from pathlib import Path
import os
import uuid

folder_prefix  = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/"    
all_file = glob.glob(folder_prefix + "*.mp4")
i = 0
for file in all_file:
    fileName = file.split('/')[-1]            #for selecting only specific folder
    ide = file.split("/")[-1].split(".")[-1]
    image_path=folder_prefix + ide + str(i)       
    if not os.path.exists(image_path):
        os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -i {} -vf fps=5 {}/{}%d.jpg".format(file,image_path,random)
    os.system(cmd)
#     flag = hashvalue(image_path, fileName , finaldic)
    i= i+1
path = '/home/link-lap-24/Downloads/golf_june7/projet/input_video'
folder = os.fsencode(path)
filenames = []
i=0;
finaldic = {}

# create hashvalues
def hashvalue(images, fileName, finaldic):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    totalCount = len(full_path)
    smallVideoList = []
    for path in full_path:
        folder_imges=path.split('/')[-1]
        hashes= imagehash.average_hash(Image.open(path),16)
        smallVideoList.append(hashes)
    finaldic[fileName] = smallVideoList
    return True

# Iterate video frames folder
for file in os.listdir(folder):
    images = path+"/mp4"+str(i)
    fileName = images.split('/')[-1]            
    flag = hashvalue(images, fileName , finaldic)
    i=i+1

# Matching hashvalues from each other like v1<=>v2
i = 0
dictInside = {}
for key in finaldic:
    newKey = key[0:-1]
    for j in range(i+1,6):
        newKey = "mp4"+ str(j)
        matchCount = 0
        for h in finaldic[key]:
            for k in finaldic[newKey]:
                if(h == k):
                    matchCount = matchCount+1
                    break
        matchingFileNAme = key + "<->" + newKey
        dictInside[matchingFileNAme] = {"matchCount": matchCount, "totalCount":len(finaldic[key])}
        j = j+1
    i = i+1

# Convert matchcount to percentile
def convertToPercent(myDict):
    percentDict = {}
    for i in myDict.keys():
        prcent = (int(myDict[i]['matchCount'])/int(myDict[i]['totalCount']))*100
        percentDict[i] = prcent
    print(percentDict)
convertToPercent(dictInside)
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
import os
import glob
import imagehash
import cv2
from PIL import Image
from pathlib import Path
import os
import uuid

folder_prefix  = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/"    
all_file = glob.glob(folder_prefix + "*.mp4")
i = 0


print(all_file)
print()
for file in all_file:
    fileName = file.split('/')[-1]            #for selecting only specific folder
#     print(fileName,"<<<<<<<<")
#     ide = file.split("/")[-1].split(".")[-1]
#     image_path=folder_prefix + ide + str(i)       
    
    input_frames = os.getcwd() + "/input_video/" + fileName.split(".")[0] + "/"
    print(input_frames)
    
    
    if not os.path.exists(input_frames):
        os.mkdir(input_frames)

#     random = str(uuid.uuid4())
#     cmd  = "ffmpeg -loglevel quiet -i {} -vf fps=5 {}/{}%d.jpg".format(file,image_path,random)
    
    cmd = f"""ffmpeg -loglevel quiet -i {file} -vf fps=5 -y {input_frames}%d.jpg"""
    print(cmd)
    print()
    os.system(cmd)
    flag = hashvalue(image_path, fileName , finaldic)
    i= i+1
    
    
path = '/home/link-lap-24/Downloads/golf_june7/projet/input_video'
folder = os.fsencode(path)
filenames = []
i=0;
finaldic = {}

# create hashvalues
def hashvalue(images, fileName, finaldic):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    totalCount = len(full_path)
    smallVideoList = []
    for path in full_path:
        folder_imges=path.split('/')[-1]
        hashes= imagehash.average_hash(Image.open(path),16)
        smallVideoList.append(hashes)
    finaldic[fileName] = smallVideoList
    return True

# Iterate video frames folder
for file in os.listdir(folder):
    images = path+"/mp4"+str(i)
    fileName = images.split('/')[-1]            
    flag = hashvalue(images, fileName , finaldic)
    i=i+1

# Matching hashvalues from each other like v1<=>v2
i = 0
dictInside = {}
for key in finaldic:
    newKey = key[0:-1]
    for j in range(i+1,6):
        newKey = "mp4"+ str(j)
        matchCount = 0
        for h in finaldic[key]:
            for k in finaldic[newKey]:
                if(h == k):
                    matchCount = matchCount+1
                    break
        matchingFileNAme = key + "<->" + newKey
        dictInside[matchingFileNAme] = {"matchCount": matchCount, "totalCount":len(finaldic[key])}
        j = j+1
    i = i+1

# Convert matchcount to percentile
def convertToPercent(myDict):
    percentDict = {}
    for i in myDict.keys():
        prcent = (int(myDict[i]['matchCount'])/int(myDict[i]['totalCount']))*100
        percentDict[i] = prcent
    print(percentDict)
convertToPercent(dictInside)
# Out:
# ['/home/link-lap-24/Downloads/golf_june7/projet/input_video/input3.mp4', '/home/link-lap-24/Downloads/golf_june7/projet/input_video/input5.mp4', '/home/link-lap-24/Downloads/golf_june7/projet/input_video/input1.mp4', '/home/link-lap-24/Downloads/golf_june7/projet/input_video/input2.mp4', '/home/link-lap-24/Downloads/golf_june7/projet/input_video/input4.mp4', '/home/link-lap-24/Downloads/golf_june7/projet/input_video/inputc6.mp4']
#
# /home/link-lap-24/Downloads/golf_june7/projet/input_video/input3/
# ffmpeg -loglevel quiet -i /home/link-lap-24/Downloads/golf_june7/projet/input_video/input3.mp4 -vf fps=5 -y /home/link-lap-24/Downloads/golf_june7/projet/input_video/input3/%d.jpg
#
# /home/link-lap-24/Downloads/golf_june7/projet/input_video/input5/
# ffmpeg -loglevel quiet -i /home/link-lap-24/Downloads/golf_june7/projet/input_video/input5.mp4 -vf fps=5 -y /home/link-lap-24/Downloads/golf_june7/projet/input_video/input5/%d.jpg
#
# ...

# %%
import os
import glob
import imagehash
import cv2
from PIL import Image
from pathlib import Path
import os
import uuid

folder_prefix  = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/"    
all_file = glob.glob(folder_prefix + "*.mp4")
i = 0
for file in all_file:
    fileName =  file.split('/')[-1]            #for selecting only specific folder
    ide = file.split("/")[-1].split(".")[-1]
    image_path=folder_prefix + ide + str(i)       
    if not os.path.exists(image_path):
        os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -loglevel quiet -i {} -vf fps=5 {}/{}%d.jpg".format(file,image_path,random)
    os.system(cmd)
#     flag = hashvalue(image_path, fileName , finaldic)
    i= i+1
# path = '/home/link-lap-24/Downloads/golf_june7/projet/input_video'
# folder = os.fsencode(path)
filenames = []
i=0
finaldic = {}

# create hashvalues
def hashvalue(images, fileName):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    totalCount = len(full_path)
    smallVideoList = []
    for path in full_path:
        folder_imges=path.split('/')[-1]
        hashes= imagehash.average_hash(Image.open(path),16)
        smallVideoList.append(hashes)
    finaldic[fileName] = smallVideoList
    return True
# Iterate video frames folder
for file in os.listdir(folder):
    images = path+"/mp4"+str(i)
    fileName = images.split('/')[-1]            
    flag = hashvalue(images, fileName)
    i=i+1

# Matching hashvalues from each other like v1<=>v2
i = 0
dictInside = {}
for key in finaldic:
    for j in range(i+1,15):
        newKey = "mp4"+ str(j)
        matchCount = 0
        for h in finaldic[key]:
            for k in finaldic[newKey]:
                if(h == k):
                    matchCount = matchCount+1
                    break
        matchingFileNAme = key + "<->" + newKey
        dictInside[matchingFileNAme] = {"matchCount": matchCount, "totalCount":len(finaldic[key])}
        j = j+1
    i = i+1

# Convert matchcount to percentile
def convertToPercent(myDict):
    percentDict = {}
    for i in myDict.keys():
        prcent = (int(myDict[i]['matchCount'])/int(myDict[i]['totalCount']))*100
        percentDict[i] = prcent
    print(percentDict)
convertToPercent(dictInside)
# Out:
# {'mp40<->mp41': 0.0, 'mp40<->mp42': 0.0, 'mp40<->mp43': 0.0, 'mp40<->mp44': 0.0, 'mp40<->mp45': 0.0, 'mp40<->mp46': 0.0, 'mp40<->mp47': 0.0, 'mp40<->mp48': 0.0, 'mp40<->mp49': 0.0, 'mp40<->mp410': 0.0, 'mp40<->mp411': 0.0, 'mp40<->mp412': 0.0, 'mp40<->mp413': 0.0, 'mp40<->mp414': 0.0, 'mp41<->mp42': 0.0, 'mp41<->mp43': 0.0, 'mp41<->mp44': 0.0, 'mp41<->mp45': 0.0, 'mp41<->mp46': 0.0, 'mp41<->mp47': 0.0, 'mp41<->mp48': 5.714285714285714, 'mp41<->mp49': 0.0, 'mp41<->mp410': 0.0, 'mp41<->mp411': 0.0, 'mp41<->mp412': 0.0, 'mp41<->mp413': 0.0, 'mp41<->mp414': 0.0, 'mp42<->mp43': 0.0, 'mp42<->mp44': 0.0, 'mp42<->mp45': 0.0, 'mp42<->mp46': 0.0, 'mp42<->mp47': 0.0, 'mp42<->mp48': 0.0, 'mp42<->mp49': 0.0, 'mp42<->mp410': 0.0, 'mp42<->mp411': 0.0, 'mp42<->mp412': 0.0, 'mp42<->mp413': 0.0, 'mp42<->mp414': 0.0, 'mp43<->mp44': 0.0, 'mp43<->mp45': 0.0, 'mp43<->mp46': 0.0, 'mp43<->mp47': 0.0, 'mp43<->mp48': 0.0, 'mp43<->mp49': 0.0, 'mp43<->mp410': 0.0, 'mp43<->mp411': 0.0, 'mp43<->mp412': 0.0, 'mp43
# ...

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = car.keys()

print(x)
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
newKey = key[0:-1]
print(newKey)
# Out:
# mp42

# %%
lis=['v1,v2,v3,v4',"tu","bh"]

lis[0:-1]
# Out:
# ['v1,v2,v3,v4', 'tu']
