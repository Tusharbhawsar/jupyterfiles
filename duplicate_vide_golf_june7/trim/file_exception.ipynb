# %%
import os

# %%
os.listdir()
# Out:
# ['input',
#  'trim.ipynb',
#  'Untitled1.ipynb',
#  'split,replace,join.ipynb',
#  'video (copy).txt',
#  '.ipynb_checkpoints',
#  'video.txt',
#  'videos',
#  'if_and_else.ipynb',
#  'def.ipynb',
#  'file.txt',
#  'videos.zip',
#  'Untitled.ipynb',
#  'string_slash_list_dictionary_json.ipynb',
#  'video.bat',
#  'output',
#  'file.ipynb',
#  'crop.ipynb',
#  'TB',
#  'os_uuid.ipynb']

# %%
os.getcwd()
# Out:
# '/home/link-lap-24/Downloads/golf_june7/trim'

# %%
# f=open('/home/link-lap-24/Downloads/golf_june7/trim.txt','w')


# tbh="/home/link-lap-24/Downloads/golf_june7/trim"

# tu=str(tbh)

# jj=tu.replacee("/" , "\")

# # up=str(f)

# print(jj)

           
# # f.replace('/','\')

# # f.write("file creating")

# # f.close()

# %%
#a for append & w for write,overwrite file & r for read the file
# split () will split the string using input character and return a list (arry) of word
# refer a save image in google txt

f=open('\\home\\link-lap-24\Downloads\golf_june7\\trim\\tushar.txt','a') 

f.write('file creating for work')

f.close()

# %%
os.getcwd()
# Out:
# '/home/link-lap-24/Downloads/golf_june7/trim'

# %%
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 print(f.read())
#
# ValueError: I/O operation on closed file.

# %%
r=open('/home/link-lap-24/Downloads/golf_june7/trim/video.txt','r')
print(r.read())
r.close()
# Out:
# file 'input1.mp4'
# file 'input2.mp4'
# file 'input3.mp4'
# file 'input4.mp4'

# %%
tb=open('/home/link-lap-24/Downloads/golf_june7/trim/video.txt','r')


for i in tb:
    token=i.split(".") #it's must to save split function in a variable and any for loop inner value
    print(len(token))
f.close
# Out:
# 2
# 2
# 2
# 2
# <function TextIOWrapper.close()>

# %%
with open('/home/link-lap-24/Downloads/golf_june7/trim/video.txt','r') as f:
    print(f.read())
# Out:
# file 'input1.mp4'
# file 'input2.mp4'
# file 'input3.mp4'
# file 'input4.mp4'

# %%
x=input('enter the no.:')
y=input('enter the no.:')

try:
    z=int(x)/int(y)
except excepttion as e:
    print('exception occured:',e)
    z=None
print("Division is :",z)
# Out:
# enter the no.:4
# enter the no.:8
# Division is : 0.5

# %%
import csv

# %%
# it read url as Source Url

with open ('high_quality.csv','r') as fl: 
    Dict=csv.DictReader(fl) #function read the csv file and change into Dictionary
    
    for i in Dict:
        print(i)      # for fatching any key value print of perticular column(i['Tags'])
# Out:
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# {'': '', 'Tags': '', 'Source Url': ''}
# ...

# %%
import pandas as pd
import csv as cv

# %%
df=pd.read_csv('high_quality.csv')

data=print(df['Source Url'].to_list())
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, na
# ...

# %%
try:
    print('tushar bhawsar')
except Exception as e:
    print("Data Annotator")
else:
    print('Fresher')
finally:
    print('student')
# Out:
# tushar bhawsar
# Fresher
# student

# %%
a=7
b=20

tb=a % b
print(tb)
# Out:
# 7

# %%
if __name__== '__main__':
    a=int(input())
    b=int(input())
    print(a//b)
    print(a/b)
# Out:
# 3
# 5
# 0
# 0.6
