# %%
import os
import glob
import imagehash
import cv2
from PIL import Image

# %%
# img1 = "/home/link-lap-24/jupyter_files/duplicate_vide_golf_june7/videos/ou1.jpg"
# img2 = "/home/link-lap-24/jupyter_files/duplicate_vide_golf_june7/videos/ou2.jpg"

# # Compute the average hash for both images
# hash1 = imagehash.average_hash(Image.open(img1), 16)
# hash2 = imagehash.average_hash(Image.open(img2), 16)

# %%
video_path = "/home/link-lap-24/jupyter_files/duplicate_vide_golf_june7/videos/"

read_path1=glob.glob(os.path.join(video_path , "*.mp4"))
print(read_path1)
# read_path=glob.glob(video_path + "*.mp4")
for i in read_path1:
    spl=os.path.splitext(os.path.basename(i))[0]
    print(spl)

# print(read_path)
# Out:
# ['/home/link-lap-24/jupyter_files/duplicate_vide_golf_june7/videos/ou1.mp4', '/home/link-lap-24/jupyter_files/duplicate_vide_golf_june7/videos/ou.mp4', '/home/link-lap-24/jupyter_files/duplicate_vide_golf_june7/videos/jdj_copy.mp4']
# ou1
# ou
# jdj_copy

# %%
import json

with open("hashes,json","r") as file:
    video_hashes=json.load(file)
    
    videos=list(video_hashes.keys())
#     print(len(videos))
    for i in range(len(videos)):
        for j in range(i +1,len(videos)):
            print(video_hashes[videos[j]])
# Out:
# ['ff6fff6f2f252f25fd2ff8f70062000000000000000000006f00ff3fc2ffc60f', 'f8fffaffbbff1cfe1cfe3cfe00fcc1f8c1fdc0fc8198009000e090bec0bf40f8', '80feff9fffffffffff87ecbf00790000000003009a05004e0000901f801f0000', 'ffffffffffff04000400847fc6ff000000000000000000000000801f801f0000', 'f8fffafffaff9cff1cfe7cfe20fec1fcc1f9c1f881d8009800e090bec2bf40f8', 'ffffffffffffffffa601000002f900e0000000000000000000000000801f0000', 'ffffffffffffffffe7ff000000c00000000000000000000000000000801f0000', 'fffffffffffffeffdc07000004f201e0000000000000000000000000801f0000', 'ffffffffffffff1f1000100012ff0018000000000000000000008009801f0000', 'f8fffafffbff9cff1cfe7cfe20fcc1fcc1fcc1fc81d8009000e090bec0bf40f8', 'ffffffffffffffffd100000050fc0078000000000000000000000009801f0000', 'f8fffafffbff9cff1cfe3cfe68fcc1fcc1f9c1f88198009800e090bec0bf40f8', 'fa57ff5fff7fff77ff41647f003c0000000000001300f80100f0909f801f4000', 'ffffffffffffffffd1000000d0fc0070000000000000000000000008801f0000', 'ffb7ffbffd953f94ffb7c4df01c80000000000000000
# ...

# %%
for i in range(1,3):
    print(i)
for i in range(2,3):
    print(i)
for i in range(3,3):
    print(i)
# Out:
# 1
# 2
# 2

# %%
def hashdictionary(folder_images):
    full_path=glob.glob(path + "*.jpg")
    
    Dict={}
    
    for folder_images in full_path:
        img_name_dict=folder_images.split('/')[-1]
        hahvalues=imagehash.average_hash(Image.open(folder_images),16)
        Dict[img_name_dict]=hahvalues
    return Dict
path='/home/link-lap-24/Downloads/golf_june7/projet/input_data/input9/'

end=hashdictionary(path)
end[16]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [32], in <cell line: 14>()
#      11 path='/home/link-lap-24/Downloads/golf_june7/projet/input_data/input9/'
#      13 end=hashdictionary(path)
# ---> 14 end[16]
#
# KeyError: 16

# %%
def hashvalue(images):
    full_path=glob.glob(image_path + "*.jpg")
    
    dictionary={}
    
    for path in full_path:
        folder_imges=path.split('/')[-1]
#         print(folder_imges)
        hashes= imagehash.average_hash(Image.open(path),16)
#         print(hashes)
        dictionary[folder_imges]=hashes
#         print(hashes)
    return dictionary
image_path='/home/link-lap-24/Downloads/golf_june7/projet/input_data/input9/'
dictionary=hashvalue(image_path)
print(dictionary)
# Out:
# {'1video58.jpg': array([[False, False,  True, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [ True,  True,  True,  True,  True, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [ True,  True,  True,  True,  True, False, False, False, False,
#         False, False, False, False, False, False, False],
# ...

# %%
image_path='/home/link-lap-24/Downloads/golf_june7/projet/input_data/input9/'

dictionary=hashvalue(image_path)
dictionary['1video1.jpg']
# Out:
# array([[False, False,  True, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [ True,  True,  True,  True,  True, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [ True,  True,  True,  True,  True, False, False, False, False,
#         False, False, False, False, False, False, False],
# ...

# %%
import os 
import uuid
import glob
import cv2
finaldic = {}
def hashvalue(images,fileName, finaldic):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    dictionary={}    
    for path in full_path:
        folder_imges=path.split('/')[-1]
        hashes= imagehash.average_hash(Image.open(path),16)
        dictionary[folder_imges]=hashes
    
#     valueName = 'V'+ str(i)
    finaldic[fileName] = dictionary
    return True

folder_prefix  = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/"

all_file = glob.glob(folder_prefix + "*.mp4")
i = 0
for file in all_file:
    fileName = file.split('/')[-1]            #finaldic[fileName] = dictionary
    ide = file.split("/")[-1].split(".")[-1]
    image_path=folder_prefix + ide + str(i)       
    if not os.path.exists(image_path):
        os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -i {} -vf fps=5 {}/{}%d.jpg".format(file,image_path,random)
    os.system(cmd)
    hashvalue(image_path, fileName , finaldic)
    i= i+1
print(finaldic,'test')
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
# example_averagehash.py

# Import dependencies
from PIL import Image
import imagehash

# Create the Hash Object of the first image
HDBatmanHash = imagehash.average_hash(Image.open('batman_hd.jpg'))
print('Batman HD Picture: ' + str(HDBatmanHash))

# Create the Hash Object of the second image
SDBatmanHash = imagehash.average_hash(Image.open('batman_sd.jpg'))
print('Batman HD Picture: ' + str(SDBatmanHash))

# Compare hashes to determine whether the pictures are the same or not
if(HDBatmanHash == SDBatmanHash):
    print("The pictures are perceptually the same !")
else:
    print("The pictures are different, distance: " + (HDBatmanHash - SDBatmanHash))

# %%
import os
import imagehash
import glob
import cv2
import uuid
import PIL
from PIL import Image


def hashes_in_dictionary(video_path,frames_path):
    
    v_full_path=glob.glob(v_path + '*.mp4')
    
    for video in v_full_path:
        v_folder_names=video.split('/')[-1]
        print(v_folder_names)
        
#         if not os.path.exists(v_folder_names):
#             os.makedirs(v_folder_names)
            
#             random=str(uuid.uuid4())
#             cmd="ffmpeg -i {} -qscalev:1 -vf fps=2 {}/{}%d.jpg".format(video,v_folder_names,random)
#             os.system(cmd)
    
v_path="/home/link-lap-24/Downloads/golf_june7/projet/input_video/"


# for fr_path in frames_path:

# %%
# Python implementation of converting
# a string into a dictionary

# initialising first string
str1 = "Jan, Feb, March"
str2 = "January | February | March"

# splitting first string
# in order to get keys
keys = str1.split(", ")

# splitting second string
# in order to get values
values = str2.split("|")

# declaring the dictionary
dictionary = {}

# Assigning keys and its
# corresponding values in
# the dictionary
for i in range(len(keys)):
    dictionary[keys[i]] = values[i]

# printing the generated dictionary
print(dictionary)
# Out:
# {'Jan': 'January ', 'Feb': ' February ', 'March': ' March'}

# %%
a = ("a", "b", "c", "d", "e", "f", "g", "h")
x = slice(2)
print(a[x])
# Out:
# ('a', 'b')

# %%
a = ("a", "b", "c", "d", "e", "f", "g", "h")
b=slice(2)
print(a[b])
# Out:
# ('a', 'b')

# %%
x = format(255, 'x')

# %%
x
# Out:
# 'ff'

# %%
valueName = 'V'+ str(i)
print(valueName)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 valueName = 'V'+ str(i)
#       2 print(valueName)
#
# NameError: name 'i' is not defined

# %%
import uuid
random = str(uuid.uuid4())
print(random)
# Out:
# f328c590-27fc-421c-992f-385cb9b72278

# %%
import os 
import uuid
import glob
import cv2

longvideoList = []
def longValueHashValue(images,fileName):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    for path in full_path:
        folder_imges=path.split('/')[-1]
        hashes= imagehash.average_hash(Image.open(path),16)
        longvideoList.append(hashes)
    return True
longVideo = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/long/output8.mp4"

fileName = longVideo.split('/')[-1]            #finaldic[fileName] = dictionary
ide = longVideo.split("/")[-1].split(".")[-1] 
image_path=longVideo + ide + "long"       
if not os.path.exists(image_path):
    os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -i {} -vf fps=5 {}/{}%d.jpg".format(longVideo,image_path,random)
    os.system(cmd)
    longValueHashValue(image_path, fileName)
print(len(longvideoList),'length=???>>>')
finaldic = {}
def hashvalue(images,fileName, finaldic):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    dictionary={}    
    matchCount = 0
    totalCount = len(full_path)
    for path in full_path:
        folder_imges=path.split('/')[-1]
        hashes= imagehash.average_hash(Image.open(path),16)
        for l in longvideoList: 
            if(l == hashes):
                matchCount = matchCount+1
            
    dictionary['matchCount'] = matchCount
    dictionary['totalCount'] = totalCount
    finaldic[fileName] = dictionary
    return True

folder_prefix  = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/"    
all_file = glob.glob(folder_prefix + "*.mp4")
i = 0
for file in all_file:
    fileName = file.split('/')[-1]            #finaldic[fileName] = dictionary
    ide = file.split("/")[-1].split(".")[-1]
    image_path=folder_prefix + ide + str(i)       
    if not os.path.exists(image_path):
        os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -i {} -vf fps=5 {}/{}%d.jpg".format(file,image_path,random)
    os.system(cmd)
    hashvalue(image_path, fileName , finaldic)
    i= i+1
print(finaldic,'test')
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
import os 
import uuid
import glob
import cv2

longvideoList = []
def longValueHashValue(images,fileName):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    for path in full_path:
        folder_imges=path.split('/')[-1]
        hashes= imagehash.average_hash(Image.open(path),16)
        longvideoList.append(hashes)
    return True
longVideo = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/long/output8.mp4"

fileName = longVideo.split('/')[-1]            #finaldic[fileName] = dictionary
ide = longVideo.split("/")[-1].split(".")[-1] 
image_path=longVideo + ide + "long"       
if not os.path.exists(image_path):
    os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -i {} -vf fps=5 {}/{}%d.jpg".format(longVideo,image_path,random)
    os.system(cmd)
    longValueHashValue(image_path, fileName)
print(len(longvideoList),'length=???>>>')
finaldic = {}
def hashvalue(images,fileName, finaldic):
    images = images + '/*.jpg'
    full_path = glob.glob(images)
    dictionary={}    
    matchCount = 0
    totalCount = len(full_path)
    smallVideoList = []
    for path in full_path:
        folder_imges=path.split('/')[-1]
        hashes= imagehash.average_hash(Image.open(path),16)
        smallVideoList.append(hashes)

    for s in range(0, len(smallVideoList)):
        for l in range(0, len(longvideoList)): 
            if(l == s):
                print(l == s, l, '---->', s, fileName)
                matchCount = matchCount+1

    dictionary['matchCount'] = matchCount
    dictionary['totalCount'] = totalCount
    finaldic[fileName] = dictionary
    return True

folder_prefix  = "/home/link-lap-24/Downloads/golf_june7/projet/input_video/"    
all_file = glob.glob(folder_prefix + "*.mp4")
i = 0
for file in all_file:
    fileName = file.split('/')[-1]            #finaldic[fileName] = dictionary
    ide = file.split("/")[-1].split(".")[-1]
    image_path=folder_prefix + ide + str(i)       
    if not os.path.exists(image_path):
        os.mkdir(image_path)
    random = str(uuid.uuid4())
    cmd  = "ffmpeg -i {} -vf fps=5 {}/{}%d.jpg".format(file,image_path,random)
    os.system(cmd)
    flag = hashvalue(image_path, fileName , finaldic)
    i= i+1
print(finaldic,'test')
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...
