# %%
import os
import glob
import natsort

# %%
vdos='/home/link-lap-24/Downloads/celebration/in/'

# %%
df=natsort.natsorted(glob.glob(vdos + "*.mp4"))

# %%
df
# Out:
# ['/home/link-lap-24/Downloads/celebration/in/1.mp4',
#  '/home/link-lap-24/Downloads/celebration/in/2.mp4',
#  '/home/link-lap-24/Downloads/celebration/in/3.mp4',
#  '/home/link-lap-24/Downloads/celebration/in/4.mp4',
#  '/home/link-lap-24/Downloads/celebration/in/5.mp4',
#  '/home/link-lap-24/Downloads/celebration/in/b_14.mp4']

# %%
for i in df:
    vi_fold=i.split(".")[0]
    cret_fold=os.path.join(vdos,vi_fold)
    os.makedirs(cret_fold)
    cmd=f"""ffmpeg -i {i} -qscale:v 1 {cret_fold}/%d.jpg"""
    os.system(cmd)
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
for i in video_list:
    path = video_path + '/' + i
    video_name = i.split(".")[0]
    output_path = os.path.join(data_path, video_name)
    os.makedirs(output_path)
    cmd = f'ffmpeg -i "{path}" -qscale:v 1 "{output_path}/%d.png"'
    os.system(cmd)
