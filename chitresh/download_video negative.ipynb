# %%
import pandas as pd
data=pd.read_csv('Basketball_Events_Clips-19-10-2023-15-02-20.csv')

# %%
data
# Out:
#         Type                         Tags  \
# 0      train                       replay
# 1      train                       replay
# 2      train                 player_focus
# 3      train           Two Pointer Jumper
# 4      train                Negative,pass
# ...      ...                          ...
# 14307  train  two_pointer_miss,layup_miss
# 14308  train           Two Pointer Jumper
# 14309  train      two_pointer_jumper_miss
# 14310  train      two_pointer_jumper_miss
# 14311  train  two_pointer_miss,layup_miss
#
#                                               Source Url  startDuration  \
# 0      https://ai-studio-new.s3-ap-south-1.amazonaws....          0.000
# 1      https://ai-studio-new.s3-ap-south-1.amazonaws....          0.000
# 2      https://ai-studio-new.s3-ap-south-1.amazonaws....          0.582
# 3      https://ai-studio-new.s3-ap-south-1.amazonaws....          3.234
# 4      https://ai-studio-new.s3-ap-south-1.amazonaws....          3.321
# ...

# %%
set(data["Tags"])
# Out:
# {'Dunk',
#  'Dunk,two_pointer',
#  'Dunk,two_pointer,two_pointer_miss,layup_miss',
#  'Dunk,two_pointer_miss,hook_miss',
#  'Dunk_miss,two_pointer_miss',
#  'Free_Throw _miss,free_throw_miss',
#  'Negative',
#  'Negative,pass',
#  'Negative,player_focus',
#  'Two Pointer Jumper',
#  'Two Pointer Jumper,layup_miss,two_pointer_miss',
#  'Two Pointer Jumper,three_pointer_miss',
#  'Two Pointer Jumper,two_pointer',
#  'Two Pointer Jumper,two_pointer,hook',
#  'Two Pointer Jumper,two_pointer_jumper_miss',
#  'Two Pointer Jumper,two_pointer_miss,hook_miss',
#  'Two Pointer Jumper,two_pointer_miss,layup_miss',
#  'free_throw',
#  'free_throw_miss',
#  'hook,two_pointer',
#  'hook,two_pointer,three_pointer_miss',
#  'hook_miss',
#  'hook_miss,two_pointer_miss',
#  'hook_miss,two_pointer_miss,Two Pointer Jumper',
#  'hook_miss,two_pointer_miss,hook,two_pointer',
#  'hook_miss,two_pointer_miss,lay up,two_pointer',
#  'hook_miss,two_pointer_miss,three_pointer',
# ...

# %%
data
# Out:
#         Type                         Tags  \
# 0      train                       replay
# 1      train                       replay
# 2      train                 player_focus
# 3      train           Two Pointer Jumper
# 4      train                Negative,pass
# ...      ...                          ...
# 14307  train  two_pointer_miss,layup_miss
# 14308  train           Two Pointer Jumper
# 14309  train      two_pointer_jumper_miss
# 14310  train      two_pointer_jumper_miss
# 14311  train  two_pointer_miss,layup_miss
#
#                                               Source Url  startDuration  \
# 0      https://ai-studio-new.s3-ap-south-1.amazonaws....          0.000
# 1      https://ai-studio-new.s3-ap-south-1.amazonaws....          0.000
# 2      https://ai-studio-new.s3-ap-south-1.amazonaws....          0.582
# 3      https://ai-studio-new.s3-ap-south-1.amazonaws....          3.234
# 4      https://ai-studio-new.s3-ap-south-1.amazonaws....          3.321
# ...

# %%
data=data[data['Type']=='train']

# %%
data=data[data["Tags"]=='two_pointer_miss,Dunk_miss']

# %%
data
# Out:
#         Type                        Tags  \
# 6194   train  two_pointer_miss,Dunk_miss
# 8021   train  two_pointer_miss,Dunk_miss
# 8026   train  two_pointer_miss,Dunk_miss
# 12102  train  two_pointer_miss,Dunk_miss
# 12180  train  two_pointer_miss,Dunk_miss
# 12344  train  two_pointer_miss,Dunk_miss
# 13049  train  two_pointer_miss,Dunk_miss
# 13063  train  two_pointer_miss,Dunk_miss
# 13248  train  two_pointer_miss,Dunk_miss
# 13368  train  two_pointer_miss,Dunk_miss
# 13401  train  two_pointer_miss,Dunk_miss
# 14235  train  two_pointer_miss,Dunk_miss
#
#                                               Source Url  startDuration  \
# 6194   https://ai-studio-new.s3-ap-south-1.amazonaws....       3.172773
# 8021   https://ai-studio-new.s3-ap-south-1.amazonaws....       2.911053
# 8026   https://ai-studio-new.s3-ap-south-1.amazonaws....       3.019990
# 12102  https://d2vaazyrxjpvvm.cloudfront.net/ai-studi...            NaN
# ...

# %%
import os

# %%
list_video=os.listdir('Two Pointer Jumper_1')

# %%
# assuming you have a column named Column1 which contains the link, iterate #through and download
import math
import wget
for index, row in data.iterrows():
#     print(row['Tags'])
    try:
        if math.isnan(row['Tags']):
            print(row['Tags'])
    except:
        
        
        while True:
        
            if row['Type']=='train':
                print(row['Source Url'])
                try:
                    video_name=row['Source Url']
                    name_video=video_name.split('/')[-1]
                    print(name_video)
                    
                    if name_video not in list_video:

                        link = wget.download(row['Source Url'],out = 'Two Pointer Jumper_1')
                    break
                except Exception as e:
                    print(e)
# Out:
# https://ai-studio-new.s3-ap-south-1.amazonaws.com/ai-studio/63f84ef7671e5d8467ac7cd5/data/8ccd6df-fe7e-242-282-f64cc85f4482mp4.mp4
# 8ccd6df-fe7e-242-282-f64cc85f4482mp4.mp4
# 100% [......................................................] 6367574 / 6367574https://ai-studio-new.s3-ap-south-1.amazonaws.com/ai-studio/63f84ef7671e5d8467ac7cd5/data/cbe4e13-af11-f06c-e27c-34ca2d37c7emp4.mp4
# cbe4e13-af11-f06c-e27c-34ca2d37c7emp4.mp4
# 100% [......................................................] 6124185 / 6124185https://ai-studio-new.s3-ap-south-1.amazonaws.com/ai-studio/63f84ef7671e5d8467ac7cd5/data/145cae1-fe58-7763-8721-2d06f2837emp4.mp4
# 145cae1-fe58-7763-8721-2d06f2837emp4.mp4
# 100% [......................................................] 6067441 / 6067441https://d2vaazyrxjpvvm.cloudfront.net/ai-studio/63f84ef7671e5d8467ac7cd5/data/4ec8c7-fdf0-1f18-78f5-36bdaa0b61.mp4
# 4ec8c7-fdf0-1f18-78f5-36bdaa0b61.mp4
# ...

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
import subprocess

cmd = f'ffmpeg -i 'https://ai-studio-new.s3-ap-south-1.amazonaws.com/ai-studio/63440f1833850aef093847bc/data/7d6f45b-31a2-52a-0462-f6e6024d5e41png.png''
result = subprocess.run(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
# Out:
#   Input In [9]
#     cmd = f'ffmpeg -i 'https://ai-studio-new.s3-ap-south-1.amazonaws.com/ai-studio/63440f1833850aef093847bc/data/7d6f45b-31a2-52a-0462-f6e6024d5e41png.png''
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# what is Hook shot in basketball
# ChatGPT
# A hook shot in basketball is a type of shooting technique where a player uses one hand to release the ball with a sweeping, hooking motion. The shot is typically taken from close to the basket, often in the post area, and it is used to shoot over a defender who is positioned between the shooter and the basket.
#
# Key characteristics of a hook shot include:
#
# One-handed release: The shooter extends their arm and flicks their wrist to create a spinning motion on the ball. This spin can make it more challenging for defenders to block the shot.
#
# High release point: The hook shot is effective because it allows the shooter to release the ball at a higher point, making it harder for defenders to reach and block the shot.
#
# Use of the backboard: Many players prefer to use the backboard when taking a hook shot because it provides a larger target and can help guide the ball into the basket.
#
# Variations: There are different types of hook shots, including the baby hook (taken with a shorter, more gentle motion) and the skyhook (popularized by basketball legend Kareem Abdul-Jabbar, where the shooter extends their arm fully and releases the ball at a very high point).
#
# Hook shots are often employed by taller players, such as centers and power forwards, who have the advantage of height and can shoot over shorter defenders. Developing a reliable hook shot can be a valuable skill for players looking to score in the low post and close to the basket.
#
#
#
#
# User
# what is Dunk shot in basketball
# ChatGPT
# A dunk shot in basketball, commonly referred to as a "dunk," is a high-flying, exciting scoring play in which a player leaps into the air and forcefully slams the basketball through the hoop with one or both hands. Dunks are typically executed when a player is close to the basket, usually near or directly above the rim. This move is one of the most iconic and crowd-pleasing plays in the game.
#
# Key characteristics of a dunk shot include:
#
# Jumping ability: Dunking requires a player to have the physical ability to jump high enough to reach the rim. Players with strong leaping ability, often referred to as "athletic" or "explosive" players, are more likely to perform dunks.
#
# Speed and momentum: Players often approach the basket with speed and momentum to generate the necessary lift for a dunk. This can be achieved through fast breaks, drives to the basket, or by receiving a pass near the hoop.
#
# Ball control: Dunking also requires good ball-handling skills to control the ball while in mid-air and guide it through the hoop. Players must coordinate their hand-eye coordination to avoid missing the shot or having it blocked by defenders.
#
# Creativity and style: Dunking allows for a high degree of creativity and style. Players often use a variety of moves and acrobatics to add flair to their dunks, such as 360-degree spins, windmills, and alley-oop dunks.
#
# Dunks can be performed in various game situations, including fast breaks, offensive rebounds, and isolation plays. Dunking over defenders is often seen as a display of dominance and athleticism, and it can energize both the team and the crowd.
#
# Some players are renowned for their dunking ability and have become household names because of their highlight-reel dunks. Notable dunkers in basketball history include Michael Jordan, LeBron James, Vince Carter, and Shaquille O'Neal, among others. Dunking has become an integral part of basketball culture and is celebrated in events like the NBA Slam Dunk Contest during All-Star Weekend.
#
#
#
#
# User
# what is layup shot in basketball
# ChatGPT
# A layup shot in basketball is a fundamental and common scoring technique where a player approaches the basket, typically with one hand, and gently releases the ball off the backboard or directly into the basket while in close proximity to the hoop. Layups are fundamental because they are used when a player is near the basket and often in a position to score easily. The goal of a layup is to score while avoiding defenders who may try to block the shot.
#
# Key characteristics of a layup shot include:
#
# One-handed or two-handed finish: While a one-handed layup is more common, players can also use both hands for added control and stability. The hand used depends on the player's preference and the specific situation.
#
# Use of the backboard: Players often use the backboard as a target to bank the ball into the hoop. This is especially important when shooting from angles where a direct shot into the basket is more challenging.
#
# Timing and footwork: Proper footwork is essential for executing a successful layup. Players approach the basket with controlled steps, often taking a series of strides or a jump step to gain momentum and maintain balance.
#
# Variations: There are variations of the layup, including the finger roll (a soft underhand release), reverse layup (shooting with the hand opposite the side of the basket), and euro step (a sidestep move to avoid defenders).
#
# Layups can be performed in various game situations, such as fast breaks, drives to the basket, and after receiving a pass near the hoop. They are considered a high-percentage shot when executed correctly because they are taken from close range.
#
# Layup skills are fundamental for basketball players of all levels, from beginners to professionals, as they are often used to score points in close-range situations. Developing proficiency in layup techniques is crucial for a player's overall offensive repertoire.
#
#
#
#
# User
# what is jumper shot in basketball
# ChatGPT
# A jumper shot in basketball, also known simply as a "jumper" or "jump shot," is a scoring technique in which a player releases the ball while jumping into the air. This type of shot is typically taken from medium to long-range distances from the basket, as opposed to layups or dunks, which are typically taken near the hoop. The jump shot is a fundamental skill in basketball and is used by players in various positions, including guards, forwards, and centers.
#
# Key characteristics of a jump shot include:
#
# Jumping and releasing: As the name suggests, the player jumps off the ground while simultaneously releasing the basketball. The upward motion provides the necessary arc to clear defenders and reach the basket.
#
# Two-handed release: Most jump shots are executed with a two-handed release, with the shooting hand (usually the dominant hand) propelling the ball towards the hoop and the off-hand providing support and balance.
#
# Use of the wrist and fingers: The shooter's wrist and fingers play a critical role in imparting backspin on the ball, which helps it maintain a straight and accurate trajectory towards the basket.
#
# Follow-through: After releasing the ball, the shooter extends their arm and maintains a consistent shooting form, with the shooting hand pointing toward the basket. A proper follow-through is important for accuracy.
#
# Jump shots can be further categorized into various types, including:
#
# Set shot: A jump shot taken with little to no forward movement. This is often used by players who have time to set their feet and square up to the basket.
#
# Pull-up jumper: A jump shot taken after dribbling or while moving forward. This allows players to create separation from defenders and shoot on the move.
#
# Fadeaway jumper: A jump shot taken while moving away from the defender, typically executed with a backward lean to create space.
#
# Step-back jumper: A jump shot taken after a step-back move, where the shooter steps away from the defender to create distance.
#
# Jump shots are a fundamental part of a player's offensive repertoire, and players often spend a significant amount of time practicing and refining their jump shot techniques. Developing a reliable jump shot can make a player a valuable scoring threat, particularly from mid-range or beyond the three-point line. Players like Stephen Curry and Kevin Durant are known for their exceptional jump shooting skills.
