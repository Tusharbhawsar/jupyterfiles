# %%
import cv2
import matplotlib.pyplot as plt

# %%
df=cv2.imread("Screenshot from 2022-10-04 10-52-45.png")

# %%
plt.imshow(df)

# %%
img=cv2.cvtColor(df,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img2=cv2.cvtColor(img,cv2.COLOR_RGB2HLS)
plt.imshow(img2)
plt.imsave("1.jpg",img2)

# %%
img3=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imsave("2.jpg",img2)
plt.imshow(img2)

# %%
import os
import time
import glob

# %%
# glob=os.listdir()

# %%
data=glob.glob('/home/link-lap-24/Downloads/cr_ball/*.png')
print(len(data))
# Out:
# 17

# %%
for i in data:
#     random=str(time.time())
    dff=cv2.imread(i)
    img22=cv2.cvtColor(dff,cv2.COLOR_BGR2RGB)

    images=cv2.cvtColor(img22,cv2.COLOR_BGR2HSV)
    plt.imsave(random,images)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
#       4 img22=cv2.cvtColor(dff,cv2.COLOR_BGR2RGB)
#       6 images=cv2.cvtColor(img22,cv2.COLOR_BGR2HSV)
# ----> 7 plt.imsave(random,images)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:2144, in imsave(fname, arr, **kwargs)
#    2142 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2143 def imsave(fname, arr, **kwargs):
# -> 2144     return matplotlib.image.imsave(fname, arr, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:1675, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673 pil_kwargs.setdefault("format", format)
#    1674 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675 image.save(fname, **pil_kwargs)
#
# ...
