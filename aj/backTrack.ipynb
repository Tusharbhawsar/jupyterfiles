# %%
distList = [[key,value['distance']] for key,value in distdict.items()]
minindex = min(distList, key = lambda x:x[1])
minindex
# Out:
# [172, 50.30159043211258]

# %%
yminIndex = min([[key,value['ballCord']] for key,value in distdict.items()], key = lambda x:x[1])
yminIndex
# Out:
# [121, [961, 349]]

# %%
def getChange(dist1,dist2):
    if dist1-dist2>0:
        return "inc"
    else:
        return "dec"

# %%
dirs = [getChange(dist[1],distList[i+1][1])  for i,dist in enumerate(distList) if i<len(distList)-2]
changeList = [(None,None)]
_ = [changeList.append((i,dirss)) for i,dirss in enumerate(dirs) if changeList[-1][1]!=dirss and len(dirss)>1]
changeList.pop(0)
changeList

# %%
dirs = [[dist[0], getChange(dist[1],distList[i+1][1])]  for i,dist in enumerate(distList) if i<len(distList)-2]
changeList = [(None,None)]
_ = [changeList.append((dirss)) for i,dirss in enumerate(dirs) if changeList[-1][1]!=dirss[1] and len(dirss)>1]
changeList.pop(0)
changeList
# Out:
# [[121, 'inc'],
#  [124, 'dec'],
#  [125, 'inc'],
#  [128, 'dec'],
#  [129, 'inc'],
#  [137, 'dec'],
#  [140, 'inc'],
#  [158, 'dec'],
#  [159, 'inc'],
#  [160, 'dec'],
#  [161, 'inc'],
#  [162, 'dec'],
#  [165, 'inc'],
#  [166, 'dec'],
#  [171, 'inc'],
#  [172, 'dec'],
#  [174, 'inc'],
#  [175, 'dec'],
#  [179, 'inc'],
#  [180, 'dec'],
#  [181, 'inc'],
#  [182, 'dec'],
#  [183, 'inc'],
#  [184, 'dec'],
#  [185, 'inc'],
#  [186, 'dec'],
#  [187, 'inc'],
#  [188, 'dec'],
#  [191, 'inc'],
#  [192, 'dec'],
#  [193, 'inc'],
#  [194, 'dec'],
#  [199, 'inc'],
#  [200, 'dec']]

# %%
changeList
# Out:
# [[121, 'inc'],
#  [124, 'dec'],
#  [125, 'inc'],
#  [128, 'dec'],
#  [129, 'inc'],
#  [137, 'dec'],
#  [140, 'inc'],
#  [158, 'dec'],
#  [159, 'inc'],
#  [160, 'dec'],
#  [161, 'inc'],
#  [162, 'dec'],
#  [165, 'inc'],
#  [166, 'dec'],
#  [171, 'inc'],
#  [172, 'dec'],
#  [174, 'inc'],
#  [175, 'dec'],
#  [179, 'inc'],
#  [180, 'dec'],
#  [181, 'inc'],
#  [182, 'dec'],
#  [183, 'inc'],
#  [184, 'dec'],
#  [185, 'inc'],
#  [186, 'dec'],
#  [187, 'inc'],
#  [188, 'dec'],
#  [191, 'inc'],
#  [192, 'dec'],
#  [193, 'inc'],
#  [194, 'dec'],
#  [199, 'inc'],
#  [200, 'dec']]

# %%
cv2.FONT_HERSHEY_COMPLEX,0.5,(0,2,255),1)
#     tr+=1


for pos in trackingBall[0:]:
    # cv2.circle(img,pos,1,(0,0,200),1)
    cv2.putText(img,f"{tr}",(pos),cv2.FONT_HERSHEY_COMPLEX,0.5,(255,2,255),1)
    tr+=1

cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
ymin_travelled = min(x[1] for x in trackingBall)

# %%
ymin_travelled

print(trackingBall.index([589, 147]))
# Out:
# 45

# %%
def getDirection(pointList):
    #width = image.shape[0]
    #height = image.shape[1]
    dx = 0
    dy = 0

    for x in range(len(pointList)-1):
        # cv2.line(image, pointList[x], pointList[x+1], [0, 255, 0], 10)
        dx += pointList[x+1][0] - pointList[x][0]  
        dy += pointList[x+1][1] - pointList[x][1] 

    x = ""
    y = ""

    if(dx < -20):
        x = "right"

    if(dx > 20):
        x = "left"

    if(dy < 0):
        y = "up"

    if(dy > 0):
        y = "down"

    # print("dx::",dx,"dy::",dy)
    # return (x+y,dx,dy)
    if abs(dx)>abs(dy):
        return (x,dx,dy)
    else:
        return (y,dx,dy)

# %%
dirs = [getDirection(trackingBall[i:i+2]) [0] for i,pos in enumerate(trackingBall) if i<len(trackingBall)-2]

# %%
print(dirs)
# Out:
# ['up', 'up', '', '', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'up', '', '', '', '', '', '', '', '', '', '', '', 'down', '', '', '', '', '', '', '', '', '', '', '', 'down', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']

# %%
print(dirs)
# Out:
# ['up', 'up', '', '', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'up', '', '', '', '', '', '', '', '', '', '', '', 'down', '', '', '', '', '', '', '', '', '', '', '', 'down', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']

# %%
dirs.index('rightdown')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 dirs.index('rightdown')
#
# ValueError: 'rightdown' is not in list

# %%
print(trackingBall[:56])
# Out:
# [[717, 274], [709, 263], [701, 252], [701, 252], [701, 252], [693, 242], [666, 212], [658, 203], [651, 195], [643, 188], [636, 182], [628, 175], [622, 169], [614, 165], [606, 159], [600, 154], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [594, 151], [589, 147], [589, 147], [589, 147], [589, 147], [589, 147], [589, 147], [589, 147], [589, 147], [589, 147], [589, 147], [589, 147]]

# %%
dirs = [getDirection(balls[i:i+2])[0]  for i,pos in enumerate(balls) if i<len(balls)-2]

# %%
changeList = [(None,None)]
_ = [changeList.append((i,dirss)) for i,dirss in enumerate(dirs) if changeList[-1][1]!=dirss and len(dirss)>1]
changeList.pop(0)
changeList
# Out:
# [(15, 'up'), (60, 'down')]

# %%
# balls = [[1212, 524], [1209, 513], [1207, 505], [1204, 496], [1200, 485], [1198, 477], [1195, 469], [1193, 463], [1191, 454], [1187, 447], [1184, 440], [1182, 435], [1179, 431], [1177, 425], [1173, 421], [1170, 418], [1168, 415], [1166, 412], [1163, 411], [1160, 408], [1157, 407], [1153, 406], [1151, 406], [1149, 406], [1146, 406], [1145, 407], [1141, 409], [1139, 411], [1136, 412], [1134, 415], [1130, 419], [1127, 422], [1125, 426], [1122, 432], [1119, 436], [1116, 441], [1113, 447], [1109, 452], [1077, 442], [1042, 432], [1007, 422], [982, 415], [982, 415], [920, 398], [895, 391], [876, 388], [852, 383], [830, 379], [811, 376], [790, 374], [771, 372], [753, 372], [735, 372], [719, 370], [704, 369], [689, 368], [677, 369], [666, 370], [643, 366], [635, 353], [627, 337], [618, 323], [607, 307], [598, 296], [587, 278], [578, 268], [570, 257], [562, 246], [555, 235], [546, 226], [537, 217], [530, 209], [522, 201], [513, 193], [506, 186], [498, 179], [489, 174], [483, 169], [475, 164], [467, 159], [461, 156], [454, 153], [448, 150], [440, 148], [433, 146], [426, 144], [419, 142], [412, 141], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [405, 140], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180], [410, 180],
[386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [386, 143], [361, 111], [363, 104], [366, 97], [368, 91], [371, 85]]
# ballss = [bal[348:]]

bal = [[857, 586], [855, 571], [853, 558], [851, 545], [849, 533], [848, 520], [847, 508], [845, 497], [844, 485], [842, 474], [840, 465], [839, 457], [838, 449], [836, 442], [835, 435], [833, 428], [832, 418], [829, 408], [828, 402], [828, 402], [828, 402], [828, 402], [828, 402], [821, 383], [821, 383], [821, 383], [821, 383], [821, 383], [821, 383], [821, 383], [821, 383], [821, 383], [821, 383], [821, 383], [821, 383], [821, 383], [803, 378], [803, 378], [803, 378], [803, 378], [803, 378], [796, 399], [795, 404], [794, 410], [792, 423], [791, 431], [790, 437], [789, 443], [788, 450], [788, 450], [790, 461], [811, 452], [830, 445], [844, 440], [862, 433], [873, 424], [890, 415], [899, 410], [909, 406], [918, 404], [926, 402], [933, 402], [938, 401], [944, 400], [944, 400], [949, 400], [963, 403], [966, 395], [967, 371], [968, 353], [972, 336], [975, 316], [976, 301], [978, 286], [980, 271], [981, 259], [983, 246], [984, 235], [986, 224], [987, 214], [988, 206], [989, 197], [990, 188], [990, 181], [991, 174], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [991, 168], [981, 149], [981, 149], [981, 149], [981, 149], [981, 149], [981, 155], [981, 155], [981, 155], [981, 155], [981, 155], [981, 155], [981, 155], [981, 155], [988, 164], [995, 180], [995, 180], [997, 187], [998, 192], [1000, 197], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202], [1001, 202]]
ballss = [bal[51:]]



for balls in ballss:

    dirs = [getDirection(balls[i:i+4])[0]  for i,pos in enumerate(balls) if i<len(balls)-2]
    changeList = [(None,None)]
    _ = [changeList.append((i,dirss)) for i,dirss in enumerate(dirs) if changeList[-1][1]!=dirss and len(dirss)>1]
    changeList.pop(0)
    changeList



    # define the true objective function
    def objective(x, a, b, c):
        return a * x + b * x**2 + c

    def objective2(x, a, b):
        return a * x + b 
    finalCords = []
    newBallsMissing = balls
    bounces = [change[0] for change in changeList][:3]
    print(bounces)

    # bounces = [0,42,43,53,54,75,76,82,83,132,133,144]
    colors = ['red','blue','black','yellow','pink','brown','green','red','blue']
    i_inc = None
    # for i in range(len(newBallsMissing)//15):
    for i in range(len(bounces)+1):
        if i < len(bounces)-1:
            if bounces[i+1]-bounces[i]<10:
            # if i==7:
                continue
            ball4Curve = newBallsMissing[bounces[i]+2:bounces[i+1]-1]
        else:
            ball4Curve = newBallsMissing[bounces[-1]:]
        # ball4Curve = newBallsMissing[15*i:15*(i+1)]
        # print(bounces[i])

        # print(x,y)
        x, y = [x[0]  for x in ball4Curve if x is not None], [
            1080-x[1]  for x in ball4Curve if x is not None]


        # curve fit
        # print(ball4Curve,bounces[i+1],bounces[i])
        # if len(x)<8:
        #     continue
            
        popt, _ = curve_fit(objective, x, y)
        a, b, c = popt

        # print('y = %.5f * x + %.5f * x^2 + %.5f' % (a, b, c))
        pyplot.scatter(x, y)

        # define a sequence of inputs between the smallest and largest known inputs
        x_line = arange(min(x)-20, max(x)+20, 1)
        # x_line = arange(0,1920,2)
        # calculate the output for the range
        y_line = objective(x_line, a, b, c)
        # print(max(x)-min(x))
        # if max(x)-min(x)<30:
        #     # print("here")
        #     # popt,_ = curve_fit(objective2,x,y)
        #     # a, b = popt

        #     # print('y = %.5f * x + %.5f ' % (a, b))
        #     # pyplot.scatter(x, y)

        #     # # define a sequence of inputs between the smallest and largest known inputs
        #     # x_line = arange(min(x)-50, max(x)+50, 1)
_ = [changeList.append((i,dirss)) for i,dirss in enumerate(dirs) if changeList[-1][1]!=dirss and len(dirss)>1]
changeList.pop(0)
print(changeList)



# define the true objective function
def objective(x, a, b, c):
    return a * x + b * x**2 + c

def objective2(x, a, b):
    return a * x + b 
finalCords = []
newBallsMissing = balls
bounces = [change[0] for change in changeList]
bounces.append(len(dirs))
print(bounces)
curveDict = {}
# bounces = [0,42,43,53,54,75,76,82,83,132,133,144]
colors = ['red','blue','black','yellow','pink','brown','green','red','blue']
i_inc = None
# for i in range(len(newBallsMissing)//15):
for i in range(len(bounces)+1):
    if i < len(bounces)-1:
        if bounces[i+1]-bounces[i]<10:
        # if i==7:
            continue
        ball4Curve = newBallsMissing[bounces[i]:bounces[i+1]]
    # else:
    #     ball4Curve = newBallsMissing[bounces[-1]:]
    # ball4Curve = newBallsMissing[15*i:15*(i+1)]
    # print(bounces[i])

    # print(x,y)
    x, y = [x[0]  for x in ball4Curve if x is not None], [
        1080-x[1]  for x in ball4Curve if x is not None]

    popt, _ = curve_fit(objective, x, y)
    a, b, c = popt

    # print('y = %.5f * x + %.5f * x^2 + %.5f' % (a, b, c))

    # define a sequence of inputs between the smallest and largest known inputs
    x_line = arange(min(x)-80, max(x)+80, 1)
    # x_line = arange(0,1920,2)
    # calculate the output for the range
    y_line = objective(x_line, a, b, c)
    if len(list(curveDict.keys()))>1:
        break
    pyplot.scatter(x, y)
    print(newBallsMissing[bounces[i+1]:])
    if i < len(bounces)-2:

        curveDict.update({i:(x_line,y_line, a,b,c, ball4Curve[-1], newBallsMissing[bounces[i+1]:][5])})
    else:
        curveDict.update({i:(x_line,y_line, a,b,c, ball4Curve[0], ball4Curve[-1])})

    # print(max(x)-min(x))
    # if max(x)-min(x)<30:
    #     # print("here")
    #     # popt,_ = curve_fit(objective2,x,y)
    #     # a, b = popt

    #     # print('y = %.5f * x + %.5f ' % (a, b))
    #     # pyplot.scatter(x, y)

    #     # # define a sequence of inputs between the smallest and largest known inputs
    #     # x_line = arange(min(x)-50, max(x)+50, 1)
    #     # # x_line = arange(0,1920,2)
    #     # # calculate the output for the range
    #     # y_line = objective2(x_line, a, b)
    #     continue

    # create a line plot for the mapping function
    pyplot.plot(x_line, y_line, '--')
    _ = [finalCords.append([x,y]) for x,y in zip(x_line[::-1],y_line[::-1])]
pyplot.show()
# Out:
# ['', '', '', '', 'down', 'down', 'down', '', '', '', '', '', '', '', '', '', '', 'down', 'down', 'down', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'down', 'down', 'down', '', '', '', '']
# [(4, 'down')]
# [4, 49]
# [[1025, 239], [1025, 239]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[157], line 124
#     122     break
#     123 pyplot.scatter(x, y)
# --> 124 print(newBallsMissing[bounces[i+1]:])
#     125 if i < len(bounces)-2:
#     127     curveDict.update({i:(x_line,y_line, a,b,c, ball4Curve[-1], newBallsMissing[bounces[i+1]:][5])})
#
# IndexError: list index out of range

# %%
curveDict.keys()
# Out:
# dict_keys([0, 3])

# %%
# edited
from intersect import intersection

keys = list(curveDict.keys())

curveintersectionDict = [[0,[balls[0][0],balls[0][0]],[balls[0][1],balls[0][1]]]]
for i, key in enumerate(keys):
    if i==len(keys)-1:
        # curveintersectionDict.append([i+1,[balls[-1][0],balls[-1][0]],[balls[-1][1],balls[-1][1]]])
        if rightup:
            curveintersectionDict.append([i+1,[x_line1[-1],x_line1[-1]],[y_line1[-1],y_line1[-1]],firstpoint1,lastpoint1])
        if leftup:
            curveintersectionDict.append([i+1,[x_line1[1],x_line1[1]],[y_line1[1],y_line1[1]],firstpoint1,lastpoint1])

        pyplot.plot(x_line1, y_line1, c="g")
        break


    x_line, y_line,_,_,_,firstpoint,lastpoint = curveDict[key]
    x_line1, y_line1,_,_,_,firstpoint1,lastpoint1 = curveDict[keys[i+1]]
    x,y = intersection(x_line, y_line,x_line1, y_line1)
    print(x,y)
    curveintersectionDict.append([i+1,x.tolist(),y.tolist(), firstpoint,lastpoint])
    pyplot.plot(x_line, y_line, c="r")




    # if i <len(keys)-1:
    #     x_line, y_line,_,_,_ = curveDict[key]
    #     x_line1, y_line1,_,_,_ = curveDict[keys[i+1]]
    #     x,y = intersection(x_line, y_line,x_line1, y_line1)
    #     curveintersectionDict.append([i+1,x.tolist(),y.tolist()])
    #     print(x,y)
    #     # print(x,y)
    #     pyplot.plot(x_line, y_line, c="r")
    # elif i+1==len(curveDict):
    #     curveintersectionDict.append([i+1,[balls[-1][0],balls[-1][0]],[balls[-1][1],balls[-1][1]]])
    #     pyplot.plot(x_line1, y_line1, c="g")



print(curveintersectionDict)
pyplot.show()
# Out:
# [1213.84631381] [678.48079272]
# [[0, [830, 830], [480, 480]], [1, [1213.8463138075317], [678.4807927182632], [1191, 407], [1238, 356]], [2, [1411, 1411], [996.5673604054346, 996.5673604054346], [1332, 190], [1410, 162]]]

# %%
# from intersect import intersection

# keys = list(curveDict.keys())

# curveintersectionDict = []
# for i, key in enumerate(keys):
#     if i == 0:
#         curveintersectionDict.append([0,[balls[0][0],balls[0][0]],[balls[0][1],balls[0][1]]])
#     elif i <len(keys)-1:
#         x_line, y_line,_,_,_ = curveDict[key]
#         x_line1, y_line1,_,_,_ = curveDict[keys[i+1]]
#         x,y = intersection(x_line, y_line,x_line1, y_line1)
#         curveintersectionDict.append([keys[i+1],x.tolist(),y.tolist()])
#         print(x,y)
#         # print(x,y)
#         pyplot.plot(x_line, y_line, c="r")
#     if i+1==len(curveDict):
#         curveintersectionDict.append([i+1,[balls[-1][0],balls[-1][0]],[balls[-1][1],balls[-1][1]]])



# print(curveintersectionDict)
# pyplot.show()

# %%
from intersect import intersection
intersectionPoints = {}
x_line, y_line,_,_,_ = curveDict[0]
x_line1, y_line1,_,_,_ = curveDict[1]
# x_line2, y_line2,_,_,_ = curveDict[2]
# x_line3, y_line3,_,_,_ = curveDict[4]

x,y = intersection(x_line, y_line,x_line1, y_line1)
# x2,y2 = intersection(x_line1, y_line1,x_line2, y_line2)
# x3,y3 = intersection(x_line2, y_line2,x_line3, y_line3)

print(x,y)
# print(x,y)
pyplot.plot(x_line, y_line, c="r")
pyplot.plot(x_line1, y_line1, c="g")
# pyplot.plot(x_line2, y_line2, c="b")
# pyplot.plot(x_line3, y_line3, c="r")

pyplot.plot(x, y, "*k")
# pyplot.plot(x2, y2, "*k")

pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 3
#       1 from intersect import intersection
#       2 intersectionPoints = {}
# ----> 3 x_line, y_line,_,_,_ = curveDict[0]
#       4 x_line1, y_line1,_,_,_ = curveDict[1]
#       5 # x_line2, y_line2,_,_,_ = curveDict[2]
#       6 # x_line3, y_line3,_,_,_ = curveDict[4]
#
# ValueError: too many values to unpack (expected 5)

# %%
curveintersectionDict[1]
# Out:
# [1, [718.9228567885012], [725.3630400591053], [788, 370], [721, 185]]

# %%
# leftUp

from numpy import arange
import pandas as pd
from scipy.optimize import curve_fit
from matplotlib import pyplot



# define the true objective function
def objective(x, a, b, c):
    return a * x + b * x**2 + c

def objective2(x, a, b):
    return a * x + b 


def intersectionbetweendetections(intersections,detections):
    # min(detections, )
    pointoconsider = [x for x in intersections if min([detection[0] for detection in detections])<x<max([detection[0] for detection in detections])]
    print(intersections,detections, pointoconsider,"*************")
    return pointoconsider 

colors = ['red','blue','black','yellow','pink','brown','green','red','blue']
i_inc = None

# curveintersectionKeyList = list(curveintersectionDict.keys())
finalCords = []
i = 0
lastxmax = None
for key,value in curveDict.items():
    print(key,i)
    _,_,a,b,c,fp,lp = value
    print(min(curveintersectionDict[i][1]), max(curveintersectionDict[i+1][1]), lastxmax, fp,lp)

    




    # if not lastxmax:
    #     x_line = arange( min(x),max(max(curveintersectionDict[i+1][1]),min(curveintersectionDict[i][1])), 1)
    #     print(min(max(curveintersectionDict[i+1][1]),min(curveintersectionDict[i][1])),max(max(curveintersectionDict[i+1][1]),min(curveintersectionDict[i][1])))
    #     lastxmax =max(max(curveintersectionDict[i+1][1]),min(curveintersectionDict[i][1]))
    #     # lastxmax = max(curveintersectionDict[i+1][1])
    # else:
    #     x_line = arange(min(min(curveintersectionDict[i+1][1]), lastxmax),max(min(curveintersectionDict[i+1][1]), lastxmax), 1)
    #     # lastxmax = max(curveintersectionDict[i+1][1])
    #     print(min(min(curveintersectionDict[i+1][1]), lastxmax),max(min(curveintersectionDict[i+1][1]), lastxmax))
    #     lastxmax =lastxmax
    if not lastxmax:
        if len(curveintersectionDict[i+1][1])>1:
            inters = intersectionbetweendetections(curveintersectionDict[i+1][1],[fp,lp])
        else:
            inters =curveintersectionDict[i+1][1]
        print(inters,min(curveintersectionDict[i][1]),"///////////////////")
        x_line = arange(inters[0],min(curveintersectionDict[i][1]))
        lastxmax = inters[0]
    else:
        print(min(curveintersectionDict[i+1][1]), lastxmax,"///////////////////")

                     # x_line = arange(min(curveintersectionDict[i+1][1]), lastxmax, 1)
        x_line = arange(min(curveintersectionDict[i+1][1]), lastxmax, 1)

        # lastxmax = max(curveintersectionDict[i+1][1])
        lastxmax =min(curveintersectionDict[i+1][1])
               
    # if not lastxmax:
    #     x_line = arange( max(curveintersectionDict[i+1][1]),min(curveintersectionDict[i][1]), 1)
    #     lastxmax =max(curveintersectionDict[i+1][1])
    # # print(x_line)
    # else:
    #     # x_line = arange(min(curveintersectionDict[i+1][1]), lastxmax, 1)
    #     x_line = arange(min(min(curveintersectionDict[i+1][1]), lastxmax),max(min(curveintersectionDict[i+1][1]), lastxmax), 1)

    #     # lastxmax = max(curveintersectionDict[i+1][1])
    #     lastxmax =lastxmax
        
    


    if i < len(curveintersectionDict)-1:i+=1
    y_line = objective(x_line, a, b, c)

    pyplot.plot(x_line, y_line, '--')
    _ = [finalCords.append([x,y]) for x,y in zip(x_line[::-1],y_line[::-1])]
    # _ = [finalCords.append([x,y]) for x,y in zip(x_line,y_line)]

pyplot.show
# Out:
# 0 0
# 829 972.9055283532556 None [956, 382] [983, 322]
# [954.3283700940285, 972.9055283532556] [[956, 382], [983, 322]] [972.9055283532556] *************
# [972.9055283532556] 829 ///////////////////
# 1 1
# 954.3283700940285 1078 972.9055283532556 [999, 173] [1006, 188]
# 1078 972.9055283532556 ///////////////////
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
curveintersectionDict
# Out:
# [[0, [911, 911], [492, 492]],
#  [1, [1233.6262463285668], [656.9218495544895], [1215, 429], [1229, 428]],
#  [2,
#   [1401, 1401],
#   [921.3515770764598, 921.3515770764598],
#   [1352, 222],
#   [1356, 216]]]

# %%
# rightup

from numpy import arange
import pandas as pd
from scipy.optimize import curve_fit
from matplotlib import pyplot



# define the true objective function
def objective(x, a, b, c):
    return a * x + b * x**2 + c

def objective2(x, a, b):
    return a * x + b 


def intersectionbetweendetections(intersections,detections):
    # min(detections, )
    pointoconsider = [x for x in intersections if min([detection[0] for detection in detections])<x<max([detection[0] for detection in detections])]
    print(intersections,detections, pointoconsider)
    return pointoconsider 

colors = ['red','blue','black','yellow','pink','brown','green','red','blue']
i_inc = None

# curveintersectionKeyList = list(curveintersectionDict.keys())
finalCords = []
i = 0
lastxmax = None
for key,value in curveDict.items():
    _,_,a,b,c,fp,lp = value
    print(min(curveintersectionDict[i][1]), max(curveintersectionDict[i+1][1]), lastxmax,fp,lp)

    if not lastxmax:
        inters = intersectionbetweendetections(curveintersectionDict[i+1][1],[fp,lp])
        print(inters)
        x_line = arange(min(curveintersectionDict[i][1]),inters[0])
        lastxmax = inters[0]
    else:
        # x_line = arange(min(lastxmax, max(curveintersectionDict[i+1][1])),max(lastxmax, max(curveintersectionDict[i+1][1])), 1)
        x_line = arange(lastxmax,max(lastxmax, max(curveintersectionDict[i+1][1])), 1)

        lastxmax = max(lastxmax, max(curveintersectionDict[i+1][1]))

    # if not lastxmax:
    #     x_line = arange(min(min(curveintersectionDict[i][1]), max(curveintersectionDict[i+1][1])),max(min(curveintersectionDict[i][1]), max(curveintersectionDict[i+1][1])), 1)
    #     # lastxmax = max(curveintersectionDict[i+1][1])
    #     lastxmax = max(min(curveintersectionDict[i][1]), max(curveintersectionDict[i+1][1]))
    #     # print(x_line)
    # else:
    #     # x_line = arange(min(lastxmax, max(curveintersectionDict[i+1][1])),max(lastxmax, max(curveintersectionDict[i+1][1])), 1)
    #     x_line = arange(min(lastxmax, max(curveintersectionDict[i+1][1])),max(lastxmax, max(curveintersectionDict[i+1][1])), 1)

    #     lastxmax = max(lastxmax, max(curveintersectionDict[i+1][1]))

    
    if i <len(curveintersectionDict)-1:
        i+=1
    y_line = objective(x_line, a, b, c)
    # print(x_line,y_line,key)
    pyplot.plot(x_line, y_line, '--')
    _ = [finalCords.append([x,y]) for x,y in zip(x_line[::-1],y_line[::-1])]
    # print("appended",finalCords)

pyplot.show
# Out:
# 830 1213.8463138075317 None [1191, 407] [1238, 356]
# [1213.8463138075317] [[1191, 407], [1238, 356]] [1213.8463138075317]
# [1213.8463138075317]
# 1213.8463138075317 1411 1213.8463138075317 [1332, 190] [1410, 162]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(finalCords)
# Out:
# [[1233.0, 656.7993993590775], [1232.0, 656.6037568805968], [1231.0, 656.408002324097], [1230.0, 656.2121356895775], [1229.0, 656.0161569770387], [1228.0, 655.8200661864803], [1227.0, 655.6238633179028], [1226.0, 655.4275483713056], [1225.0, 655.2311213466892], [1224.0, 655.0345822440534], [1223.0, 654.837931063398], [1222.0, 654.6411678047234], [1221.0, 654.4442924680293], [1220.0, 654.2473050533158], [1219.0, 654.050205560583], [1218.0, 653.8529939898306], [1217.0, 653.6556703410588], [1216.0, 653.4582346142677], [1215.0, 653.2606868094572], [1214.0, 653.0630269266272], [1213.0, 652.8652549657779], [1212.0, 652.6673709269091], [1211.0, 652.469374810021], [1210.0, 652.2712666151135], [1209.0, 652.0730463421864], [1208.0, 651.87471399124], [1207.0, 651.6762695622742], [1206.0, 651.4777130552891], [1205.0, 651.2790444702845], [1204.0, 651.0802638072605], [1203.0, 650.8813710662171], [1202.0, 650.6823662471543], [1201.0, 650.4832493500719], [1200.0, 650.2840203749704], [1199.0, 650.0846
# ...

# %%
curveintersectionKeyList = list(curveintersectionDict.keys())
# curveintersectionDict[curveintersectionKeyList[1]][0][1]
curveintersectionKeyList
# Out:
# [1, 2, 3, 4]

# %%
print(bounces)
# Out:
# [0, 24, 37, 58, 112, 127]

# %%
from numpy import arange
import pandas as pd
from scipy.optimize import curve_fit
from matplotlib import pyplot

# define the true objective function
def objective(x, a, b, c):
 return a * x + b * x**2 + c



x, y = [x[0]  for x in balls[0:9] if x is not None], [
    1080-x[1]  for x in balls[0:9] if x is not None]
# x = pd.DataFrame(x)
# y = pd.DataFrame(y)

# curve fit
popt, _ = curve_fit(objective, x, y)
# summarize the parameter values
a, b, c = popt
print('y = %.5f * x + %.5f * x^2 + %.5f' % (a, b, c))
# plot input vs output



pyplot.scatter(x, y)
# pyplot.scatter(x1, y1)

# define a sequence of inputs between the smallest and largest known inputs
x_line = arange(min(x)-20, max(x)+50, 1)
# x_line = arange(min(x)-20,668.69181919,2)
# calculate the output for the range
y_line = objective(x_line, a, b, c)

# x_line1 = arange(min(x1)-150, max(x1)+20, 1)
# x_line1 = arange(668.69181919, max(x1)+20, 2)

# calculate the output for the range
# y_line1 = objective(x_line1, a1, b1, c1)

# create a line plot for the mapping function
pyplot.plot(x_line, y_line, '--', color='red')
# pyplot.plot(x_line1, y_line1, '--', color='blue')

pyplot.show()
# Out:
# y = -1.16773 * x + 0.00026 * x^2 + 1508.88120

# %%
totalerror  = sum([pos[1]-objective(pos[0],a,b,c) for pos in balls[0:26]])
totalerror
# Out:
# -7889.181329570871
