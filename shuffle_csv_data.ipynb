# %%
from moviepy.editor import VideoFileClip
import pandas as pd

df=pd.read_csv("American-Foootball-Scoreboard-Detection-12-01-2024-14-55-56.csv")


# # List of video file paths    
# # video_files = ["video1.mp4", "video2.mp4", "video3.mp4"]

# # Function to get timestamp of a video
# def get_video_timestamp(data):
#     clip = VideoFileClip(video_file)
#     return clip.duration

# # Print timestamps of all videos
# for video_file in data:
#     print(f"Timestamp of {video_file}: {get_video_timestamp(video_file)} seconds")

# %%
data=df.sample(frac=1)
data
# Out:
#        Type  Original Id              Tags  \
# 4522  train         4523        score_card
# 4999  train          139        score_card
# 1659  train         1660            replay
# 4605  train         4606        score_card
# 1191  train         1192        score_card
# ...     ...          ...               ...
# 5354  train          135        score_card
# 4696  train         4697        score_card
# 5414  train          142        score_card
# 2878  train         2879  score_card,other
# 4047   test         4048        score_card
#
#                                              Source Url  \
# 4522  https://d2vaazyrxjpvvm.cloudfront.net/ai-studi...
# 4999  https://d2vaazyrxjpvvm.cloudfront.net/ai-studi...
# 1659  https://d2vaazyrxjpvvm.cloudfront.net/ai-studi...
# 4605  https://d2vaazyrxjpvvm.cloudfront.net/ai-studi...
# 1191  https://d2vaazyrxjpvvm.cloudfront.net/ai-studi...
# ...                                                 ...
# ...

# %%
data.to_csv('random.csv')
