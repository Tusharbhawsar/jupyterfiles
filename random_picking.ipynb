# %%
import uuid
import urllib
import pandas as pd
import random
import glob
import natsort
import os

# %%
data=pd.read_csv("3_pointer.csv")

df = data.sample(frac = 1)

df
# Out:
#        Type                Tags  \
# 4299  train  Three Point Jumper
# 143   train  Three Point Jumper
# 2254  train  Three Point Jumper
# 3779  train  Three Point Jumper
# 4899  train  Three Point Jumper
# ...     ...                 ...
# 4459  train  Three Point Jumper
# 2586  train  Three Point Jumper
# 596   train  Three Point Jumper
# 468   train  Three Point Jumper
# 1980  train  Three Point Jumper
#
#                                              Source Url  startDuration  \
# 4299  https://videos.nba.com/nba/pbp/media/2022/02/2...            NaN
# 143   https://videos.nba.com/nba/pbp/media/2022/02/1...       5.590043
# 2254  https://videos.nba.com/nba/pbp/media/2022/02/1...            NaN
# 3779  https://videos.nba.com/nba/pbp/media/2022/11/2...            NaN
# 4899  https://videos.nba.com/nba/pbp/media/2022/02/2...            NaN
# ...                                                 ...            ...
# 4459  https://videos.nba.com/nba/pbp/media/2022/02/2...            NaN
# ...

# %%
for i in df['Source Url']:
#     print(i)
    name=str(uuid.uuid4())
    
    urllib.request.urlretrieve(i,name)
# Out:
# <class 'pandas.core.series.Series'>

# %%
video_path="/home/link-lap-24/Downloads/3pointer/"

cmp_path=natsort.natsorted(glob.glob(video_path + "*.mp4"))
cmp_path
# Out:
# ['/home/link-lap-24/Downloads/3pointer/1.mp4',
#  '/home/link-lap-24/Downloads/3pointer/2.mp4',
#  '/home/link-lap-24/Downloads/3pointer/3.mp4',
#  '/home/link-lap-24/Downloads/3pointer/4.mp4',
#  '/home/link-lap-24/Downloads/3pointer/5.mp4',
#  '/home/link-lap-24/Downloads/3pointer/6.mp4',
#  '/home/link-lap-24/Downloads/3pointer/7.mp4',
#  '/home/link-lap-24/Downloads/3pointer/8.mp4',
#  '/home/link-lap-24/Downloads/3pointer/9.mp4',
#  '/home/link-lap-24/Downloads/3pointer/10.mp4',
#  '/home/link-lap-24/Downloads/3pointer/11.mp4',
#  '/home/link-lap-24/Downloads/3pointer/12.mp4',
#  '/home/link-lap-24/Downloads/3pointer/13.mp4',
#  '/home/link-lap-24/Downloads/3pointer/14.mp4',
#  '/home/link-lap-24/Downloads/3pointer/15.mp4',
#  '/home/link-lap-24/Downloads/3pointer/16.mp4',
#  '/home/link-lap-24/Downloads/3pointer/17.mp4',
#  '/home/link-lap-24/Downloads/3pointer/18.mp4',
#  '/home/link-lap-24/Downloads/3pointer/19.mp4',
#  '/home/link-lap-24/Downloads/3pointer/20.mp4',
# ...

# %%
for i in cmp_path:
    vid_name=i.split(".")[0]
    cr_path=os.path.join(video_path,vid_name)
    os.makedirs(cr_path)
    cmd=f"""ffmpeg -i {i} -qscale:v 1 {cr_path}/%d.png"""
    os.system(cmd)
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...
